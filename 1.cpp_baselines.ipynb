# %% [markdown]
# ## Compare CPP generation

# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import plot_style_utils

methods = ['Baseline', 'SMILES GA', 'Graph GA', 'SMILES LSTM$_{hc}$', 'HELM-GPT$_{Reinvent}$', 'HELM-GPT$_{Reinvent+CPL}$']
spearman = [-4.787, -4.720, -4.648, -4.589, -4.416, -4.414]
spearman_std = [0.210, 0.145, 0.086, 0.082, 0.010, 0.010]
fig, ax = plot_style_utils.simple_ax()
plot_style_utils.set_pub_plot_context(context="talk")
plot_style_utils.prettify_ax(ax)

ax.errorbar(methods, spearman, yerr=spearman_std, fmt='o', ecolor=plot_style_utils.CAT_PALETTE[0])
ax.set_ylabel('Permeability (log $cm/s$)')
ax.set_ylim([-5.1, -4.3])
ax.set_xticks(methods)
ax.set_xticklabels(methods, rotation=45, ha='right')
plot_style_utils.save_for_pub(fig=fig, path='figures/cpp/cpp_gen_model_cmp')
# Out:
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.
